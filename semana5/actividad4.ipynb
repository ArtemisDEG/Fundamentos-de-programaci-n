# %% [markdown]
# ### ACTIVIDAD 5 PRINCIPAL
#
# Crear una **aplicación interactiva en Python** que demuestre el uso integral de
# **tuplas**, **diccionarios**, **manipulación de cadenas de texto (strings)** y
# **manejo robusto de excepciones**, estructurada a través de un **menú principal
# modular** controlado por un ciclo. El usuario debe poder seleccionar por número qué
# sección desea ejecutar (Tuplas, Diccionarios, Excepciones, Strings o Finalizar) y
# el programa debe delegar cada tarea a funciones modulares.
# Este reto integra la creación y manipulación de **tuplas** (Tema 13), los
# **diccionarios** con claves y valores (Tema 14), los bloques **try-except** con
# excepciones específicas (Tema 15) y los **métodos de strings** con conteo de
# palabras (Tema 16), además de consolidar las funciones con y sin retorno vistas en
# semanas anteriores.

# %%
numeros = (8, 3, 5, 1, 9)

contactos = {
    "Paulo": "5551234567",
    "Juan": "5559876543",
    "Ana": "5554567890"
}

def sumar(numeros):
    return sum(numeros)

def buscar(contactos, nombre):
    return contactos.get(nombre)

def contar_palabras(mensaje):
    return len(mensaje.split())

def tuplas():
    print("Tuplas")
    print(f"Tercer número {numeros[2]}")
    numero1 = int(input("Ingresa un número"))
    numero2 = int(input("Ingresa otro número"))
    nueva_tupla = numeros + (numero1, numero2)
    lista = list(nueva_tupla)
    lista.sort()
    print(f"Tupla nueva: {nueva_tupla}")
    print(f"Lista ordenada: {lista}")
    print(f"Suma {sumar(nueva_tupla)}")

def diccionarios():
    print("Diccionario")
    nombre = input("Ingresa el nombre del nuevo contacto")
    telefono = input("Ingresa el teléfono")
    contactos[nombre] = telefono
    print("Contactos")

    for nombre in contactos:
        print(nombre)
    nombre = input("¿Qué contacto quieres buscar?")
    telefono = buscar(contactos, nombre)
    if telefono:
        print(f"Teléfono {telefono}")
    else:
        print("Contacto no encontrado")

def excepciones():
    print("Excepciones")
    try:
        numero1 = int(input("Ingresa el primer número"))
        numero2 = int(input("Ingresa el segundo número"))

        print(f"Suma {numero1 + numero2}")

        try:
            print(f"División {numero1 / numero2}")

        except ZeroDivisionError:
            print("No se puede dividir entre cero")

    except:
        print("Ingresa números enteros válidos")
def strings():
    print("Strings")

    mensaje = input("Ingresa un mensaje")

    print(f"Longitud {len(mensaje)}")
    print(f"Mayúsculas {mensaje.upper()}")
    mensaje = mensaje.replace("Python", "programación")
    print(f"Mensaje cambiado {mensaje}")
    print(f"Palabras {contar_palabras(mensaje)}")

while True:
    print("Menú")
    print("1. Tuplas")
    print("2. Diccionarios")
    print("3. Excepciones")
    print("4. Strings")
    print("5. Finalizar")

    opcion = int(input("Elige una opción"))

    if opcion == 1:
        tuplas()
    elif opcion == 2:
        diccionarios()
    elif opcion == 3:
        excepciones()
    elif opcion == 4:
        strings()
    elif opcion == 5:
        print("Programa finalizado")
        break
    else:
        print("Opción inválida")
# Out:
# Menú
# 1. Tuplas
# 2. Diccionarios
# 3. Excepciones
# 4. Strings
# 5. Finalizar
# Tuplas
# Tercer número 5
# Tupla nueva: (8, 3, 5, 1, 9, 34, 3)
# Lista ordenada: [1, 3, 3, 5, 8, 9, 34]
# Suma 63
# Menú
# 1. Tuplas
# 2. Diccionarios
# 3. Excepciones
# 4. Strings
# 5. Finalizar
# Programa finalizado

# %% [markdown]
# ## EJERCICIO EXTRA 1
# **Enunciado:** Crea una tupla `calificaciones = (7.5, 9.0, 8.0, 6.5, 10.0)`.
# Imprime la tercera calificación, captura dos calificaciones nuevas con `input()` y
# anéxalas en una nueva tupla. Convierte la nueva tupla en lista, ordénala **de mayor
# a menor** y muestra la suma de todos los elementos usando una función que retorne
# el valor.
# **Entrada:**

# %%
def suma_calif(calificaciones):
    total = 0
    for c in calificaciones:
        total += c
    return total

calificaciones = (7.5, 9.0, 8.0, 6.5, 10.0)

nueva_calificacion = float(input("Ingresa una nueva calificación: "))

calif_new = calificaciones + (nueva_calificacion,)
lista_calificaciones = list(calif_new)
lista_calificaciones.sort(reverse=True)

print(f"Tercera calificación {calificaciones[2]}")
print(f"Nueva tupla: {calif_new}")
print(f"Calificaciones ordenadas {lista_calificaciones}")
print(f"La suma de todas las calificaciones es {suma_calif(lista_calificaciones)}")
# Out:
# Tercera calificación 8.0
# Nueva tupla: (7.5, 9.0, 8.0, 6.5, 10.0, 67.0)
# Calificaciones ordenadas [67.0, 10.0, 9.0, 8.0, 7.5, 6.5]
# La suma de todas las calificaciones es 108.0

# %% [markdown]
# ## EJERCICIO EXTRA 2
# **Enunciado:** Crea un diccionario `agenda` con tres contactos iniciales (`"Ana":
# "555-0101"`, `"Luis": "555-0102"`, `"Mía": "555-0103"`). Captura un nuevo contacto
# (nombre y teléfono) con `input()` y agrégalo al diccionario. Luego imprime todos
# los nombres con `keys()` en una sola línea y, con una función que retorne el valor,
# busca y muestra el teléfono del nuevo contacto.

# %%
def buscar_con(agenda, nombre):
    return agenda.get(nombre, "No se ha encontrado el contacto")


agenda = {
    "Betin": "67-6969",
    "Carlitos": "67-1234",
    "Nocha": "67-5644"
}
new_con = input("nombre del nuevo contacto")
new_num = input("Teléfono del nuevo contacto: ")
agenda [new_con.capitalize()] = new_num
print("Contactos registrados ", end="")
for n in agenda.keys():
    print(n, end=", ")

nombre = input("Escribe el nombre del contacto que buscas")
num_tel = buscar_con(agenda, nombre.capitalize())
print(f"El número de {nombre.capitalize()} es: {num_tel}")
# Out:
# Contactos registrados Betin, Carlitos, Nocha, Nicogoat, El número de  es: No se ha encontrado el contacto

# %% [markdown]
# ## EJERCICIO EXTRA 3
# **Enunciado:** Escribe un programa que pida dos números enteros. Implementa un
# bloque `try-except` que capture `ValueError` (caracteres no numéricos o vacíos) con
# un mensaje controlado y un bloque específico `except ZeroDivisionError` que muestre
# un mensaje amigable si el segundo número es cero. En caso exitoso, muestra la
# división del primero entre el segundo.

# %%
while True:
    try:
        dividendo = int(input("Ingresa un número entero para el dividendo"))
        divisor = int(input("Ingresa otro número entero para el divisor"))
        break
    except ValueError:
        print("Pusiste un dato erróneo, vuelve a intentar")
try:
    resultado = dividendo / divisor
    print(f"{dividendo} dividido entre {divisor} es {resultado}")
except ZeroDivisionError:
    print("No es posible dividir entre cero, vuelve a ingresar un divisor distinto de 0")

# %% [markdown]
# ## EJERCICIO EXTRA 4
# **Enunciado:** Crea una variable `mensaje = "Python es un lenguaje poderoso"`.
# Imprime su longitud con `len()`, conviértelo a mayúsculas, reemplaza la palabra
# `"Python"` por `"programación"` y, con una función que retorne el conteo, muestra
# cuántas palabras contiene el mensaje original

# %%
def cont_palabras(mensaje):
    palabras = mensaje.split()
    return len(palabras)

mensaje = "Python es un lenguaje poderoso"
len_msj = len(mensaje)
msj_upper = mensaje.upper()
py_rplc = mensaje.replace("Python", "Programación")

print(f"La longitud del mensaje es de {len_msj} caracteres")
print(f"Mayúsculas {msj_upper}")
print(f"Texto reemplazado: {py_rplc}")
print(f"El mensaje tiene {cont_palabras(mensaje)} palabras")
